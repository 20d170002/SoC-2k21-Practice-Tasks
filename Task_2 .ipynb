# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('/content/master.csv')
df
# Out:
#                             country  ...       generation
# 0                           Albania  ...     Generation X
# 1                           Albania  ...           Silent
# 2                           Albania  ...     Generation X
# 3                           Albania  ...  G.I. Generation
# 4                           Albania  ...          Boomers
# ...                             ...  ...              ...
# 21788  Saint Vincent and Grenadines  ...           Silent
# 21789  Saint Vincent and Grenadines  ...          Boomers
# 21790  Saint Vincent and Grenadines  ...     Generation X
# 21791  Saint Vincent and Grenadines  ...       Millenials
# 21792      Saint Vincent and Grenad  ...              NaN
#
# [21793 rows x 12 columns]

# %%
df.describe()
# Out:
#                year   suicides_no  ...  HDI for year  gdp_per_capita ($)
# count  27820.000000  27820.000000  ...   8364.000000        27820.000000
# mean    2001.258375    242.574407  ...      0.776601        16866.464414
# std        8.469055    902.047917  ...      0.093367        18887.576472
# min     1985.000000      0.000000  ...      0.483000          251.000000
# 25%     1995.000000      3.000000  ...      0.713000         3447.000000
# 50%     2002.000000     25.000000  ...      0.779000         9372.000000
# 75%     2008.000000    131.000000  ...      0.855000        24874.000000
# max     2016.000000  22338.000000  ...      0.944000       126352.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Mode for each variable

# %%
 
df.mode(axis=0,numeric_only =True, dropna =True)
# Out:
#      year  suicides_no  ...  HDI for year  gdp_per_capita ($)
# 0  2009.0          0.0  ...         0.713                1299
# 1     NaN          NaN  ...         0.772                2303
# 2     NaN          NaN  ...         0.888                4104
#
# [3 rows x 6 columns]

# %% [markdown]
# Median

# %%
df.median(axis =0)
# Out:
# year                    2001.000
# suicides_no               21.000
# population            396400.000
# suicides/100k pop          5.520
# HDI for year               0.782
# gdp_per_capita ($)      9467.500
# dtype: float64

# %% [markdown]
# Skew

# %%
print(df.skew(axis = 0, skipna = True))
# Out:
# year                  -0.160241
# suicides_no           10.352910
# population             4.459414
# suicides/100k pop      2.963414
# HDI for year          -0.300877
# gdp_per_capita ($)     1.963470
# dtype: float64

# %% [markdown]
# Interquartile range

# %%
my_list= ['year', 'suicides_no','population','suicides/100k pop','HDI for year','gdp_per_capita ($)']
for col in my_list:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  print(IQR)
# Out:
# 13.0
# 128.0
# 1388644.75
# 15.700000000000001
# 0.14200000000000002
# 21427.0

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# Too few bins

# %%
df.hist(bins = 10)
plt.tight_layout()

# %% [markdown]
# Too many bins

# %%
df.hist(bins = 1000)
plt.tight_layout()

# %% [markdown]
# Good number of bins

# %%
df.hist(bins = 75)
plt.tight_layout()

# %% [markdown]
# Box-and- whiskers plot

# %%
my_list= ['year', 'suicides_no','population','suicides/100k pop','HDI for year','gdp_per_capita ($)']
for col in my_list:
  df[col].plot(kind='box')
  plt.show()
  plt.tight_layout()
